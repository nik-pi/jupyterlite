# %% [markdown]
# <style>
# .jp-Cell[data-tags~="hide"] {
#     display: none !important;
# }
# </style>

# %%
# 🚀 Complete the function below
def add_numbers(a, b):
    # User writes code here
    return a-b

# %%
# ✅ Hidden Test Cases (User Can't See This)
def check_answer():
    test_cases = [
        ((2, 3), 5),
        ((-1, 1), 0),
        ((0, 0), 0)
    ]
    
    try:
        for (inputs, expected) in test_cases:
            result = add_numbers(*inputs)
            assert result == expected, f"❌ Test Failed: add_numbers{inputs} → Expected {expected}, got {result}"
        
        print("✅ All test cases passed!")
    
    except Exception as e:
        print(f"⚠️ Error: {str(e)}")

# %%
feedback = check_answer()  # Runs automatically
# Out:
# ⚠️ Error: ❌ Test Failed: add_numbers(2, 3) → Expected 5, got -1
